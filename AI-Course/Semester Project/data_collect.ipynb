# %%
import uuid
import os
import time
import cv2

PATH = os.path.join(os.getcwd(),'data','images')#.replace("\\","/") # /data/images
labels = ['happy','neutral','surprised']
num_imgs = 50

cap = cv2.VideoCapture(1)

# %%
for label in labels:
    print("Image for {}".format(label))
    time.sleep(1)

    for img_num in range(num_imgs):
        print("Image {} of {}".format(img_num+1,num_imgs))
        ret, frame = cap.read()
        if ret:
            img_name = os.path.join(PATH,label,str(uuid.uuid1())+'.jpg')#.replace("\\","/")
            print(cv2.imwrite(img_name,frame))
            cv2.imshow(label,frame)
            print("Image saved at {}".format(img_name))
            time.sleep(1)
        else:
            print("Error capturing image")
            break
        
        
        if cv2.waitKey(1) == ord('q'):
                cap.release()
                cv2.destroyAllWindows()
                break

    cv2.destroyAllWindows()
    print ("\n\n GOING FOR NEXT LABEL \n\n")
# Out:
# Image for happy
# Image 1 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\happy\cd9ef421-ee9e-11ed-90d3-ac50defee8e4.jpg
# Image 2 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\happy\ce3c10d7-ee9e-11ed-b21b-ac50defee8e4.jpg
# Image 3 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\happy\ced7f779-ee9e-11ed-9f47-ac50defee8e4.jpg
# Image 4 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\happy\cf7396f2-ee9e-11ed-a17d-ac50defee8e4.jpg
# Image 5 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\happy\d00fe909-ee9e-11ed-bbe1-ac50defee8e4.jpg
# Image 6 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\happy\d0ab7e37-ee9e-11ed-baa7-ac50defee8e4.jpg
# Image 7 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\happy\d147035a-ee9e-11ed-a36a-ac50defee8e4.jpg
# Image 8 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\happy\d1e263e8-ee9e-11ed-b8ba-ac50defee8e4.jpg
# Image 9 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\happy\d27e0ae4-ee9e-11ed-b564-ac50defee8e4.jpg
# Image 10 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\happy\d31a1d12-ee9e-11ed-85de-ac50defee8e4.jpg
#
#
#  GOING FOR NEXT LABEL
#
#
# Image for sad
# Image 1 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\sad\d44ed859-ee9e-11ed-aad0-ac50defee8e4.jpg
# Image 2 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\sad\d4ec9ad3-ee9e-11ed-9fa7-ac50defee8e4.jpg
# Image 3 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\sad\d588f8ca-ee9e-11ed-a33a-ac50defee8e4.jpg
# Image 4 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\sad\d624b3e9-ee9e-11ed-9b7a-ac50defee8e4.jpg
# Image 5 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\sad\d6c0f32b-ee9e-11ed-82b0-ac50defee8e4.jpg
# Image 6 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\sad\d75c9e5a-ee9e-11ed-ae26-ac50defee8e4.jpg
# Image 7 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\sad\d7f8cb4c-ee9e-11ed-8c17-ac50defee8e4.jpg
# Image 8 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\sad\d894cf7b-ee9e-11ed-b698-ac50defee8e4.jpg
# Image 9 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\sad\d9307a81-ee9e-11ed-9efa-ac50defee8e4.jpg
# Image 10 of 10
# True
# Image saved at d:\Git\AI-Sentiment-Analysis-Roman-Urdu\data\images\sad\d9cccff5-ee9e-11ed-bd61-ac50defee8e4.jpg
#
#
#  GOING FOR NEXT LABEL

# %%
# folder = PATH

# for filename in os.listdir(folder):
#     img = cv2.imread(os.path.join(folder,filename))
#     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     cv2.imwrite(os.path.join(folder,filename),gray)
#     cv2.imshow('gray',gray)        

#     time.sleep(0.1)
#     if cv2.waitKey(1) == ord('q'):      
#         break
    
# cap.release()
# cv2.destroyAllWindows()
